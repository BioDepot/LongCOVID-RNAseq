# %% [markdown]
# ### Uses R v4.3.3.

# %% [markdown]
# ### Uncomment to install BiocManager and DESeq2.  Comment back out after running once.  It's not necessary to reinstall every time the notebook is ran.

# %%
# if (!require("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")
# BiocManager::install(version = "3.18")
# BiocManager::install(c("edgeR"))

# %% [markdown]
# ### Uncomment out each package individually and run the cell to install each package.  Do this one at a time and watch the terminal output to see if any additional dependencies need to be installed on your system.  This is espeically true on Linux where you need to install other packages from the package manager.

# %%
# install.packages('readr', version='2.1.5')
# install.packages('dplyr', version='1.1.4')
# install.packages('plotly', version='4.10.4')

# %%
library(readr)
library(dplyr)

library(edgeR)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: limma

# %% [markdown]
# # Differential expression analysis of RNA-seq Data using edgeR: A comparative study of Ryan and Vlasov datasets reflecting healthy versus survivors of severe acute COVID-19.

# %% [markdown]
# ### Introduction:
# This analysis focuses on the DEGs analysis of two datasets, Ryan Et al and Vlasov Et al that were uniformly processed using the Bwb software, using the edgeR package set to FDR < 0.05 and a log2foldchange = 1.25.  The input sample sheet intergrates metadata from both datasets and filters the gene expression data acoordingly. The overall aim is to identify key genes that reflect significant expression differences between the two groups of participants (Healthy versus survivors of severe active COVID-19). The compendium was built using samples from Australia (group A) and Russia (Group H) as shown in the diagram below pathway (iv).
#
# ### Specific Objectives
# 1. **Data Processing** - Importing and cleaning the metadata
# 2. **Filtering out Low Expression Genes** - Dropping genes with low expression to improve statistical power
# 3. **Normalization** - Using Trimmed Mean of M-values to adjust for differences in sequencing depth
# 4. **Differential expression analysis** - Using a negative binomial exact test (see here for the packge documentation)
# 5. **Extract and interpret top DEGs** - to highlight their biological relevance
# 6. **Set-up for downstream GSEA** - use the outputs to create rank lists for GSEA (different notebook)

# %% [markdown]
# ![Study design](./images/Study_design.png)

# %% [markdown]
# ### Data Processing - Importing and cleaning the metadata
#
# In this section, we import the normalized counts matrix from Bwb's uniform processing as our input for the Ryan Et al part of the dataset.  We will later filter it to keep only the relevant samples using our sample sheet created using a different notebook.
#
# The input file is cleaned by removing suffixes from the column headers to allow for congruence with other datasets that we will concatenate with.  We will sort the columns for consistency and then perform a sanity check by display the head to show only a few rows of the output.

# %% [markdown]
# ## Change the Ryan Gene Counts location by updating the read.csv() value.

# %%
# Read Ryan counts
ryan.counts <- as.matrix(read.csv("./data/Ryan/genesCounts.csv", sep="\t",row.names="Name"))

# Edit sample names in dataframe
colnames(ryan.counts) <- sapply(strsplit(colnames(ryan.counts), "_"), `[`, 1)

# Order the dataframe by column name
ryan.counts <- ryan.counts[, sort(colnames(ryan.counts))]

head(ryan.counts)
# Out:
#                 SRR14076246 SRR14076247 SRR14076248 SRR14076249 SRR14076250
# ENSG00000268674  0           0            0           0          0
# ENSG00000271254 72          50          203         199         96
# ENSG00000275063  2           5            0           0          0
# ENSG00000277856  0           1            0           0          0
# ENSG00000276345  0           0            6           0          0
# ENSG00000278633  4           0            7           7          2
#                 SRR14076251 SRR14076252 SRR14076253 SRR14076254 SRR14076255 ⋯
# ENSG00000268674   0           1          0            2           1         ⋯
# ENSG00000271254 130          75         76          228         181         ⋯
# ENSG00000275063   0           5          8            1           0         ⋯
# ENSG00000277856   0           2          1            0           0         ⋯
# ENSG00000276345   8         111         72          151         113         ⋯
# ENSG00000278633   0          10          0           12           2         ⋯
#                 SRR15510595 SRR15510596 SRR15510597 SRR15510598 SRR15510599
# ENSG00000268674   2           0           5           0           0
# ENSG00000271254 215         318         169         146         269
# ENSG00000275063   9           0           1           4           5
# ENSG00000277856   0           1           0           1           1
# ENSG00000276345   0           0           0           0           5
# ENSG00000278633   9           8          22           1          11
#                 SRR15510600 SRR15510601 SRR15510602 SRR15510603 SRR15510604
# ENSG00000268674   0           0           1           1          0
# ENSG00000271254 241         257         154         279         94
# ENSG00000275063   0           0           0           2          0
# ENSG00000277856   0           0           0           0          0
# ENSG00000276345   2           8         432           5          0
# ENSG00000278633  16          19           2           7          0

# %% [markdown]
# We also want to see the dimensions of our normalized count matrix which will be useful as we concatenate with the Vlasov Et al dataset.  In
# this case, we have 38,592 genes in the rows and 152 samples in columns all together.

# %%
dim(ryan.counts)
# Out:
# [1] 38592   152

# %% [markdown]
# We perform similar actions with regard to the Vlasov Et al dataset in the next 2 cells.

# %% [markdown]
# ## Change the Vlasov Gene Counts location by updating the read.csv() value.

# %%
# Read Vlasov counts
vlasov.counts <- as.matrix(read.csv("./data/Vlasov/genesCounts.csv", sep="\t",row.names="Name"))

# Edit sample names in dataframe
colnames(vlasov.counts) <- sapply(strsplit(colnames(vlasov.counts), "_"), `[`, 1)

# Order the dataframe by column name
vlasov.counts <- vlasov.counts[, sort(colnames(vlasov.counts))]

head(vlasov.counts)
# Out:
#                 SRR16317814 SRR16317815 SRR16317816 SRR16317817 SRR16317818
# ENSG00000268674   0           0           0           0           0
# ENSG00000271254  70          84          57          50          31
# ENSG00000275063 148         118         415         474         121
# ENSG00000277856 101          78         173         168          48
# ENSG00000276345 185         151         127         120          85
# ENSG00000278633   5          13           8           3           4
#                 SRR16317819 SRR16317820 SRR16317821 SRR16317822 SRR16317823
# ENSG00000268674  0            0          0            0           0
# ENSG00000271254 28           42         31           85          72
# ENSG00000275063 99           11         12          117         129
# ENSG00000277856 54            9         24           76          81
# ENSG00000276345 83          127         34           41          98
# ENSG00000278633  2           10          3           13          10
#                 SRR16317824 SRR16317825 SRR16317826 SRR16317827 SRR16317828
# ENSG00000268674  0           0            0           0           0
# ENSG00000271254 68          62           94         105          64
# ENSG00000275063 15          29          164         221         507
# ENSG00000277856 15          26          109         136         325
# ENSG00000276345  0           0          121         100         202
# ENSG00000278633 15          12            4           5          13
#                 SRR16317829
# ENSG00000268674   0
# ENSG00000271254  89
# ENSG00000275063 530
# ENSG00000277856 361
# ENSG00000276345 191
# ENSG00000278633   2

# %%
dim(vlasov.counts)
# Out:
# [1] 38592    16

# %% [markdown]
# As we can see here, the number of genes (rows) in Vlasov Et al is also 38,592 just like in the Ryan Et al data set.  We have
# fewer total samples (columns) with only 16 as oppossed to Ryan Et al which had 152 samples.  The process of subsetting will lead to a more
# balanced dataset compendium for comparison.

# %% [markdown]
# ### Loading the metadata
#
# Now that we have the normalized data with counts matrix from each group (Ryan and Vlasov), we need the metadata which will guide us in
# subsetting our data with respect to clinical attributes like presence or healthy, fatal cases, and survivors of severe acute COVID-19. We include the sample sheets for our desired comparisons which are those that were healty and the survivors of severe acute COVID-19.
#
# We also prepare the metadata dataset by removing the extra index column, combining all relevant sample sheets for inclusion, then sorting by sample name "Run".

# %% [markdown]
# ## Change the Compendium metadata locations by updating the read_tsv() values.

# %%
# Read Andrew's Compendium data: Group A - Ryan
sample.sheet.healthy.af = read_tsv("./Andrews_Compendium/output/sample_sheet_healthy_af.csv")
sample.sheet.healthy.am = read_tsv("./Andrews_Compendium/output/sample_sheet_healthy_am.csv")

# Remove first column from dataframes
sample.sheet.healthy.af <- sample.sheet.healthy.af[c(2:length(colnames(sample.sheet.healthy.af)))]
sample.sheet.healthy.am <- sample.sheet.healthy.am[c(2:length(colnames(sample.sheet.healthy.am)))]

# Concatenate dataframes
ryan.sample.sheet.healthy <- rbind(sample.sheet.healthy.af, sample.sheet.healthy.am)

# Sort dataframe by Run (Sample) column
ryan.sample.sheet.healthy <- arrange(ryan.sample.sheet.healthy, Run)

ryan.sample.sheet.healthy
# Out:
# New names:
# • `` -> `...1`
# Rows: 7 Columns: 35
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (26): Run, Assay Type, BioProject, BioSample, Center Name, Consent, DAT...
# dbl   (7): ...1, Age, AvgSpotLen, Bases, Bytes, version, RIN
# dttm  (2): ReleaseDate, create_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...1`
# Rows: 7 Columns: 35
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (26): Run, Assay Type, BioProject, BioSample, Center Name, Consent, DAT...
# dbl   (7): ...1, Age, AvgSpotLen, Bases, Bytes, version, RIN
# dttm  (2): ReleaseDate, create_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    Run         Age Assay Type AvgSpotLen Bases       BioProject  BioSample
# 1  SRR14076274 65  RNA-Seq    300        17132068500 PRJNA717662 SAMN18499988
# 2  SRR14076275 55  RNA-Seq    300        18290564100 PRJNA717662 SAMN18499987
# 3  SRR14076280 34  RNA-Seq    300        15407664600 PRJNA717662 SAMN18499982
# 4  SRR14076281 48  RNA-Seq    300        15462196200 PRJNA717662 SAMN18499981
# 5  SRR14076285 63  RNA-Seq    300        17168881500 PRJNA717662 SAMN18499909
# 6  SRR14076286 27  RNA-Seq    300        18766087200 PRJNA717662 SAMN18499946
# 7  SRR14076291 52  RNA-Seq    300        15353712600 PRJNA717662 SAMN18499941
# 8  SRR14076292 54  RNA-Seq    300        17904928800 PRJNA717662 SAMN18499940
# 9  SRR14076319 70  RNA-Seq    300        15545828400 PRJNA717662 SAMN18499928
# 10 SRR14076320 61  RNA-Seq    300        18904142100 PRJNA717662 SAMN18499927
# 11 SRR14076325 28  RNA-Seq    300        14604722100 PRJNA717662 SAMN18499919
# 12 SRR14076326 61  RNA-Seq    300        15591648600 PRJNA717662 SAMN18499918
# 13 SRR14076331 31  RNA-Seq    300        18027805200 PRJNA717662 SAMN18499921
# 14 SRR14076332 58  RNA-Seq    300        17072835000 PRJNA717662 SAMN18499920
#    Bytes      Center Name Consent ⋯ version Sample Name sex    source_name
# 1  5577168394 GEO         public  ⋯ 1       GSM5212344  female Peripheral blood
# 2  5941597180 GEO         public  ⋯ 1       GSM5212345  male   Peripheral blood
# 3  5011739338 GEO         public  ⋯ 1       GSM5212350  male   Peripheral blood
# 4  5036146643 GEO         public  ⋯ 1       GSM5212351  male   Peripheral blood
# 5  5593291175 GEO         public  ⋯ 1       GSM5212355  female Peripheral blood
# 6  6099144065 GEO         public  ⋯ 1       GSM5212356  male   Peripheral blood
# 7  4995757233 GEO         public  ⋯ 1       GSM5212361  female Peripheral blood
# 8  5852173368 GEO         public  ⋯ 1       GSM5212362  male   Peripheral blood
# 9  5062379739 GEO         public  ⋯ 1       GSM5212389  male   Peripheral blood
# 10 6158544368 GEO         public  ⋯ 1       GSM5212390  male   Peripheral blood
# 11 4771620972 GEO         public  ⋯ 1       GSM5212395  female Peripheral blood
# 12 5075532185 GEO         public  ⋯ 1       GSM5212396  female Peripheral blood
# 13 5867251424 GEO         public  ⋯ 1       GSM5212401  female Peripheral blood
# 14 5552111822 GEO         public  ⋯ 1       GSM5212402  female Peripheral blood
#    SRA Study subject_id Timepoint tissue           RIN Sample_Number
# 1  SRP312283 HC1        Control   Peripheral blood 8.5 Sample-37
# 2  SRP312283 HC6        Control   Peripheral blood 8.8 Sample-45
# 3  SRP312283 HC2        Control   Peripheral blood 8.0 Sample-38
# 4  SRP312283 HC7        Control   Peripheral blood 8.5 Sample-46
# 5  SRP312283 HC4        Control   Peripheral blood 8.4 Sample-39
# 6  SRP312283 HC8        Control   Peripheral blood 8.6 Sample-47
# 7  SRP312283 HC5        Control   Peripheral blood 7.8 Sample-40
# 8  SRP312283 HC9        Control   Peripheral blood 8.5 Sample-48
# 9  SRP312283 HC3        Control   Peripheral blood 8.5 Sample-85
# 10 SRP312283 HC14       Control   Peripheral blood 8.7 Sample-94
# 11 SRP312283 HC11       Control   Peripheral blood 8.5 Sample-87
# 12 SRP312283 HC16       Control   Peripheral blood 8.2 Sample-86
# 13 SRP312283 HC12       Control   Peripheral blood 8.5 Sample-88
# 14 SRP312283 HC17       Control   Peripheral blood 8.6 Sample-95

# %% [markdown]
# We then subset the output to only include the the sample name "Run" and "disease-severity" columns where we only want
# those that are healthy.  There are 14 cases that fit this criteria.

# %%
# Reduce and convert ryan_sample_sheet_healthy into sheet that can be concatenated
ryan.sample.sheet.healthy.reduced = ryan.sample.sheet.healthy[c("Run", "disease_severity")]
                                            
ryan.sample.sheet.healthy.reduced
# Out:
#    Run         disease_severity
# 1  SRR14076274 Healthy
# 2  SRR14076275 Healthy
# 3  SRR14076280 Healthy
# 4  SRR14076281 Healthy
# 5  SRR14076285 Healthy
# 6  SRR14076286 Healthy
# 7  SRR14076291 Healthy
# 8  SRR14076292 Healthy
# 9  SRR14076319 Healthy
# 10 SRR14076320 Healthy
# 11 SRR14076325 Healthy
# 12 SRR14076326 Healthy
# 13 SRR14076331 Healthy
# 14 SRR14076332 Healthy

# %% [markdown]
# We perform the same operations on the Vlasov Et al dataset to yield 10 samples where participants had healed from severe acute
# COVID-19.

# %% [markdown]
# ## Change the Compendium metadata locations by updating the read_tsv() values.

# %%
# Read Andrew's Compendium data: Group H - Vlasov
vlasov.metadata.h = read.csv("./Andrews_Compendium/output/vlasov_sample_sheet_covid_h.csv")

vlasov.metadata.h
# Out:
#    Run         age Assay.Type AvgSpotLen Bases     batch   BioProject
# 1  SRR16317816 79  RNA-Seq    50         628696450 Batch 1 PRJNA771040
# 2  SRR16317817 79  RNA-Seq    50         634761750 Batch 1 PRJNA771040
# 3  SRR16317818 74  RNA-Seq    50         563743800 Batch 1 PRJNA771040
# 4  SRR16317819 74  RNA-Seq    50         598788600 Batch 1 PRJNA771040
# 5  SRR16317822 72  RNA-Seq    50         614993050 Batch 1 PRJNA771040
# 6  SRR16317823 72  RNA-Seq    50         641257450 Batch 1 PRJNA771040
# 7  SRR16317824 59  RNA-Seq    50         582362500 Batch 1 PRJNA771040
# 8  SRR16317825 59  RNA-Seq    50         612843900 Batch 1 PRJNA771040
# 9  SRR16317828 63  RNA-Seq    50         561074100 Batch 1 PRJNA771040
# 10 SRR16317829 63  RNA-Seq    50         625675900 Batch 1 PRJNA771040
#    BioSample    Bytes     Center.Name ⋯ rin rna_extraction_time
# 1  SAMN22249190 288277508 GEO         ⋯ 9.2 2020-07-12T13:00:00Z
# 2  SAMN22249192 291102651 GEO         ⋯ 9.2 2020-07-12T13:00:00Z
# 3  SAMN22249193 258757934 GEO         ⋯ 8.8 2020-12-09T13:20:00Z
# 4  SAMN22249194 274689760 GEO         ⋯ 8.8 2020-12-09T13:20:00Z
# 5  SAMN22249197 281985244 GEO         ⋯ 7.5 2020-11-21T13:20:00Z
# 6  SAMN22249198 294617577 GEO         ⋯ 7.5 2020-11-21T13:20:00Z
# 7  SAMN22249199 267232855 GEO         ⋯ 9.2 2020-12-02T00:00:00Z
# 8  SAMN22249200 280920183 GEO         ⋯ 9.2 2020-12-02T00:00:00Z
# 9  SAMN22249204 257577161 GEO         ⋯ 9.6 2020-12-03T11:00:00Z
# 10 SAMN22249205 286817487 GEO         ⋯ 9.6 2020-12-03T11:00:00Z
#    create_date          version sample_extraction_time Sample.Name
# 1  2021-10-13T15:53:00Z 1       07.12.2020 6:00        GSM5624885
# 2  2021-10-13T15:54:00Z 1       07.12.2020 6:00        GSM5624886
# 3  2021-10-13T15:52:00Z 1       12/8/2020 17:00        GSM5624887
# 4  2021-10-13T15:52:00Z 1       12/8/2020 17:00        GSM5624888
# 5  2021-10-13T15:53:00Z 1       11/20/2020 17:00       GSM5624891
# 6  2021-10-13T15:53:00Z 1       11/20/2020 17:00       GSM5624892
# 7  2021-10-13T15:53:00Z 1                              GSM5624893
# 8  2021-10-13T15:52:00Z 1                              GSM5624894
# 9  2021-10-13T15:52:00Z 1       12/2/2020 19:30        GSM5624897
# 10 2021-10-13T15:57:00Z 1       12/2/2020 19:30        GSM5624898
#    source_name                                        SRA.Study survival_status
# 1  blood of patient with COVID-19 114 – replication 1 SRP341246 survived
# 2  blood of patient with COVID-19 114 – replication 2 SRP341246 survived
# 3  blood of patient with COVID-19 126 – replication 1 SRP341246 survived
# 4  blood of patient with COVID-19 126 – replication 2 SRP341246 survived
# 5  blood of patient with COVID-19 51 – replication 1  SRP341246 survived
# 6  blood of patient with COVID-19 51 – replication 2  SRP341246 survived
# 7  blood of patient with COVID-19 96 – replication 1  SRP341246 survived
# 8  blood of patient with COVID-19 96 – replication 2  SRP341246 survived
# 9  blood of patient with COVID-19 99 – replication 1  SRP341246 survived
# 10 blood of patient with COVID-19 99 – replication 2  SRP341246 survived
#    tissue
# 1  blood
# 2  blood
# 3  blood
# 4  blood
# 5  blood
# 6  blood
# 7  blood
# 8  blood
# 9  blood
# 10 blood

# %%
# Reduce and convert vlasov.metadata.h into sheet that can be concatenated
vlasov.metadata.h.reduced = vlasov.metadata.h[c("Run", "survival_status")]
colnames(vlasov.metadata.h.reduced)[2] <- "disease_severity"
                                            
vlasov.metadata.h.reduced
# Out:
#    Run         disease_severity
# 1  SRR16317816 survived
# 2  SRR16317817 survived
# 3  SRR16317818 survived
# 4  SRR16317819 survived
# 5  SRR16317822 survived
# 6  SRR16317823 survived
# 7  SRR16317824 survived
# 8  SRR16317825 survived
# 9  SRR16317828 survived
# 10 SRR16317829 survived

# %%
# Create dataframe from Gene Counts that only contains samples from compendium
ryan.counts.of.interest <- ryan.counts[, ryan.sample.sheet.healthy$Run]

head(ryan.counts.of.interest)
# Out:
#                 SRR14076274 SRR14076275 SRR14076280 SRR14076281 SRR14076285
# ENSG00000268674   0           0          0            2          0
# ENSG00000271254 153          68         59          141         87
# ENSG00000275063   0           0          0            0          0
# ENSG00000277856   0           0          0            0          0
# ENSG00000276345   0         110         80            0          2
# ENSG00000278633   0          14          2            6          2
#                 SRR14076286 SRR14076291 SRR14076292 SRR14076319 SRR14076320
# ENSG00000268674   0          0            0           1           0
# ENSG00000271254 127         97          161         129         149
# ENSG00000275063   2          5           10          14           1
# ENSG00000277856   4          0            0           1           1
# ENSG00000276345   2          0          239           0           2
# ENSG00000278633   0          0            0           6           0
#                 SRR14076325 SRR14076326 SRR14076331 SRR14076332
# ENSG00000268674  0            0           0           1
# ENSG00000271254 71          271         138         178
# ENSG00000275063  8            2           8           0
# ENSG00000277856  1            1           1           0
# ENSG00000276345  7            0         140         149
# ENSG00000278633  1           12           0           0

# %%
# Create dataframe from Gene Counts that only contains samples from compendium
vlasov.counts.of.interest <- vlasov.counts[, vlasov.metadata.h$Run]

head(vlasov.counts.of.interest)
# Out:
#                 SRR16317816 SRR16317817 SRR16317818 SRR16317819 SRR16317822
# ENSG00000268674   0           0           0          0            0
# ENSG00000271254  57          50          31         28           85
# ENSG00000275063 415         474         121         99          117
# ENSG00000277856 173         168          48         54           76
# ENSG00000276345 127         120          85         83           41
# ENSG00000278633   8           3           4          2           13
#                 SRR16317823 SRR16317824 SRR16317825 SRR16317828 SRR16317829
# ENSG00000268674   0          0           0            0           0
# ENSG00000271254  72         68          62           64          89
# ENSG00000275063 129         15          29          507         530
# ENSG00000277856  81         15          26          325         361
# ENSG00000276345  98          0           0          202         191
# ENSG00000278633  10         15          12           13           2

# %% [markdown]
# Here, we will combine the Ryan and Vlasov subsetted datasets into one using rbind().  We will then make the disease severity
# attribute our factor in preparation for analysis. Finally we will do a sanity check for visual reassurance.

# %%
# Concatinate Ryan and Vlasov counts of interest
counts.of.interest <- cbind(ryan.counts.of.interest, vlasov.counts.of.interest)

dim(counts.of.interest)
# Out:
# [1] 38592    24

# %%
# Remove Genes that only contain 0s
counts.of.interest.filtered <- counts.of.interest[apply(counts.of.interest != 0, 1, sum) != 0,]
dim(counts.of.interest.filtered)
# Out:
# [1] 34174    24

# %%
# Concatinate Ryan and Vlasov metadata
metadata <- rbind(ryan.sample.sheet.healthy.reduced, vlasov.metadata.h.reduced)

metadata$disease_severity <- factor(metadata$disease_severity)

metadata
# Out:
#    Run         disease_severity
# 1  SRR14076274 Healthy
# 2  SRR14076275 Healthy
# 3  SRR14076280 Healthy
# 4  SRR14076281 Healthy
# 5  SRR14076285 Healthy
# 6  SRR14076286 Healthy
# 7  SRR14076291 Healthy
# 8  SRR14076292 Healthy
# 9  SRR14076319 Healthy
# 10 SRR14076320 Healthy
# 11 SRR14076325 Healthy
# 12 SRR14076326 Healthy
# 13 SRR14076331 Healthy
# 14 SRR14076332 Healthy
# 15 SRR16317816 survived
# 16 SRR16317817 survived
# 17 SRR16317818 survived
# 18 SRR16317819 survived
# 19 SRR16317822 survived
# 20 SRR16317823 survived
# 21 SRR16317824 survived
# 22 SRR16317825 survived
# 23 SRR16317828 survived
# 24 SRR16317829 survived

# %% [markdown]
# Next, we will create a DGEList object which will be the foundation of our analysis.  This method (See help() of the package) will help us filter genes based on expression levels, normalize the gene counts, create a design matrix for comparison, then it will estimate dispersion
# (which is the variance in gene expression).  After this, it will perform statistical testing.

# %%
# Defining two groups and assigning to the variable "group"
group <- factor(c(rep(1,14), rep(2, 10)))

# %%
# Preparing the data for normalization, filtering, and DEA
y <- DGEList(counts=counts.of.interest.filtered, group=group)

# %%
# Filtering out genes to keep only those with more than 3 copies per million in at least 5 samples.
dim(y)
keep <- rowSums(cpm(y)>3) > 5
table(keep)
# Out:
# [1] 34174    24
# keep
# FALSE  TRUE
# 20815 13359

# %%
# Removing those genes that were filter out to only keep the 13,359 genes
y <- y[keep, , keep.lib.sizes=FALSE]
tokeep = rownames(y)
dim(y)
# Out:
# [1] 13359    24

# %%
# # Normalization with edgeR
y <- calcNormFactors(y)

# %%
# Creating the Design matrix
design <- model.matrix(~group)

# %%
# Estimating dispersions
y <- estimateDisp(y)
# Out:
# Using classic mode.

# %%
# Inferring differential expression
et <- exactTest(y)

# %%
# Subsetting top DEGs
top20.genes <- rownames(topTags(et, n=20)$table)
top50.genes <- rownames(topTags(et, n=50)$table)
top100.genes <- rownames(topTags(et, n=100)$table)

# %%
# Obtaining expression levels of top 20 genes from counts of interest
raw.cnts.top20 <- counts.of.interest[top20.genes, ]

# %%
# Heatmap visualization of top 20 genes
heatmap(as.matrix(raw.cnts.top20), Colv=NA, Rowv=NA)
# Out:
# plot without title

# %%
# Obtaining expression levels of top 50 genes from counts of interest
raw.cnts.top50 <- counts.of.interest[top50.genes, ]

# %%
# Heatmap visualization of top 50 genes
heatmap(as.matrix(raw.cnts.top50), Colv=NA, Rowv=NA)
# Out:
# plot without title

# %%
# Obtaining expression levels of top 100 genes from counts of interest
raw.cnts.top100 <- counts.of.interest[top100.genes, ]

# %%
# Heatmap visualization of top 100 genes
heatmap(as.matrix(raw.cnts.top100), Colv=NA, Rowv=NA)
# Out:
# plot without title

# %%
# Extracting the top differentially expressed genes
deg_results_AvsH <- topTags(et, n = Inf)$table
head(deg_results_AvsH)
# Out:
#                 logFC    logCPM   PValue        FDR
# ENSG00000197753 7.659879 4.231953  0.000000e+00  0.000000e+00
# ENSG00000289740 4.001168 8.507075  0.000000e+00  0.000000e+00
# ENSG00000286067 7.484003 4.084483 5.701518e-321 2.538886e-317
# ENSG00000261416 6.837965 4.398011 1.630860e-300 5.446665e-297
# ENSG00000255857 5.441330 5.740958 4.582442e-249 1.224337e-245
# ENSG00000266036 8.215285 2.921202 1.880578e-247 4.187107e-244

# %% [markdown]
# ### Notice
#
# The next slide can be saved as a .csv excel spread sheet by uncommenting the code snippet while leaving the comment with the '#'.

# %%
# Ensure row names (gene IDs) are saved as a column
#deg_results_AvsH$GeneID <- rownames(deg_results_AvsH)

# Save the file with GeneID included
#write.csv(deg_results_AvsH, file = file.path(getwd(), "deg_results_AvsH.csv"), row.names = FALSE)
